# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
all_features = pd.read_csv('LogFor_griRun/extracted_features.csv')
#Reorder and display columns
all_features = all_features[['oid', 'filtercode', 'source_id_01', 'apogee_id_01', 'ra', 'dec',
   'Amplitude', 'AndersonDarling', 'Autocor_length', 'Beyond1Std',
       'CAR_mean', 'CAR_sigma', 'CAR_tau', 'Con', 'Eta_e',
       'FluxPercentileRatioMid20', 'FluxPercentileRatioMid35',
       'FluxPercentileRatioMid50', 'FluxPercentileRatioMid65',
       'FluxPercentileRatioMid80', 'Freq1_harmonics_amplitude_0',
       'Freq1_harmonics_amplitude_1', 'Freq1_harmonics_amplitude_2',
       'Freq1_harmonics_amplitude_3', 'Freq1_harmonics_rel_phase_0',
       'Freq1_harmonics_rel_phase_1', 'Freq1_harmonics_rel_phase_2',
       'Freq1_harmonics_rel_phase_3', 'Freq2_harmonics_amplitude_0',
       'Freq2_harmonics_amplitude_1', 'Freq2_harmonics_amplitude_2',
       'Freq2_harmonics_amplitude_3', 'Freq2_harmonics_rel_phase_0',
       'Freq2_harmonics_rel_phase_1', 'Freq2_harmonics_rel_phase_2',
       'Freq2_harmonics_rel_phase_3', 'Freq3_harmonics_amplitude_0',
       'Freq3_harmonics_amplitude_1', 'Freq3_harmonics_amplitude_2',
       'Freq3_harmonics_amplitude_3', 'Freq3_harmonics_rel_phase_0',
       'Freq3_harmonics_rel_phase_1', 'Freq3_harmonics_rel_phase_2',
       'Freq3_harmonics_rel_phase_3', 'Gskew', 'LinearTrend', 'MaxSlope',
       'Mean', 'Meanvariance', 'MedianAbsDev', 'MedianBRP', 'PairSlopeTrend',
       'PercentAmplitude', 'PercentDifferenceFluxPercentile', 'PeriodLS',
       'Period_fit', 'Psi_CS', 'Psi_eta', 'Q31', 'Rcs', 'Skew',
       'SlottedA_length', 'SmallKurtosis', 'Std', 'StetsonK', 'StetsonK_AC',
       'StructureFunction_index_21', 'StructureFunction_index_31',
       'StructureFunction_index_32',
]]

all_features.rename(columns={col: f"FEETS_{col}" for col in all_features.columns if col not in ['oid', 'filtercode', 'source_id_01', 'apogee_id_01']}, inplace=True)

# %%
# from astroquery.gaia import Gaia
# job = Gaia.launch_job(
#                       "solution_id,ref_epoch,ra_dec_corr,astrometric_n_obs_al, "
#                       "matched_transits,duplicated_source,phot_variable_flag "
#                       "from gaiadr3.gaia_source order by source_id")
# r = job.get_results()
# print(r['ra_dec_corr'])
# ra_dec_corr

# %%
display(all_features)
# Out:
#                      oid filtercode         source_id_01     apogee_id_01  \
# 0     2M00000317+5821383         zg   422737314373993984  806104300021105
# 1     2M00000546+6152107         zg   429530195985183744  806108200000898
# 2     2M00000549+1524008         zg  2772085696588395776  499115200000339
# 3     2M00000549+1524008         zr  2772085696588395776  499115200000339
# 4     2M00000549+1524008         zi  2772085696588395776  499115200000339
# ...                  ...        ...                  ...              ...
# 2100  2M00264472+5754521         zr   421924706561379712  773115100018757
# 2101  2M00264513+5621329         zg   421724281904012928  773111100010058
# 2102  2M00264513+5621329         zr   421724281904012928  773111100010058
# 2103  2M00264514+7525370         zg   539553106195073920  854107300001200
# 2104  2M00264514+7525370         zr   539553106195073920  854107300001200
#
#       FEETS_ra  FEETS_dec  FEETS_Amplitude  FEETS_AndersonDarling  \
# 0     0.013233  58.360631         0.092366               1.000000
# 1     0.022897  61.869629         0.077303               1.000000
# 2     0.022915  15.399985         0.042002               1.000000
# 3     0.022915  15.399985         0.045834               1.000000
# 4     0.022915  15.399985         0.040320               1.000000
# ...        ...        ...              ...                    ...
# 2100  6.686432  57.914492         0.042459               1.000000
# 2101  6.688154  56.359128         0.112163               0.996984
# 2102  6.688154  56.359128         0.115139               1.000000
# 2103  6.688064  75.427032         0.069418               1.000000
# 2104  6.688064  75.427032         0.034038               1.000000
#
#       FEETS_Autocor_length  FEETS_Beyond1Std  ...  FEETS_Rcs  FEETS_Skew  \
# 0                      1.0          0.173189  ...   0.209585   -1.953084
# 1                      1.0          0.156791  ...   0.167867    2.323520
# 2                      1.0          0.065646  ...   0.063496   -9.220631
# 3                      1.0          0.054963  ...   0.047779   -2.468877
# 4                      1.0          0.099010  ...   0.086717    5.366229
# ...                    ...               ...  ...        ...         ...
# 2100                   1.0          0.017921  ...   0.055373   21.377780
# 2101                   3.0          0.290875  ...   0.125134   -0.369533
# 2102                   5.0          0.268496  ...   0.186696   -0.246111
# 2103                   1.0          0.197309  ...   0.145798    1.717456
# 2104                   1.0          0.086134  ...   0.074515    1.683393
#
#       FEETS_SlottedA_length  FEETS_SmallKurtosis  FEETS_Std  FEETS_StetsonK  \
# 0                       1.0            42.886313   0.058062        0.633054
# 1                       1.0            27.294514   0.045306        0.640288
# 2                       1.0           143.120317   0.038214        0.429507
# 3                       1.0           146.464150   0.043700        0.416801
# 4                       1.0            54.507330   0.028932        0.492611
# ...                     ...                  ...        ...             ...
# 2100                    1.0           543.947119   0.079398        0.249590
# 2101                    7.0             4.459043   0.061704        0.780748
# 2102                   13.0             1.838520   0.057020        0.759456
# 2103                    2.0            17.459482   0.038561        0.671115
# 2104                    1.0            25.909725   0.025389        0.543084
#
#       FEETS_StetsonK_AC  FEETS_StructureFunction_index_21  \
# 0              0.475413                          2.080292
# 1              0.593543                          1.421371
# 2              0.459191                          3.122827
# 3              0.383977                          2.474708
# 4              0.489438                          1.942954
# ...                 ...                               ...
# 2100           0.318702                          2.261789
# 2101           0.839196                          1.769848
# 2102           0.823022                          2.078621
# 2103           0.613072                          1.255667
# 2104           0.535157                          1.971852
#
#       FEETS_StructureFunction_index_31  FEETS_StructureFunction_index_32
# 0                             3.250333                          1.595917
# 1                             1.507039                          1.400216
# 2                             5.998420                          2.028486
# 3                             4.165865                          1.700804
# 4                             3.153580                          2.124146
# ...                                ...                               ...
# 2100                          3.881672                          1.869999
# 2101                          2.462687                          1.459912
# 2102                          3.203380                          1.553684
# 2103                          0.952338                          1.182023
# 2104                          3.003503                          1.846058
#
# [2105 rows x 69 columns]

# %%
counter = 0
for col in all_features.columns:
    print(f"[{counter}] {col}, {all_features[col].dtypes}")
    counter = counter + 1
# Out:
# [0] oid, object
# [1] filtercode, object
# [2] source_id_01, int64
# [3] apogee_id_01, int64
# [4] FEETS_ra, float64
# [5] FEETS_dec, float64
# [6] FEETS_Amplitude, float64
# [7] FEETS_AndersonDarling, float64
# [8] FEETS_Autocor_length, float64
# [9] FEETS_Beyond1Std, float64
# [10] FEETS_CAR_mean, float64
# [11] FEETS_CAR_sigma, float64
# [12] FEETS_CAR_tau, float64
# [13] FEETS_Con, float64
# [14] FEETS_Eta_e, float64
# [15] FEETS_FluxPercentileRatioMid20, float64
# [16] FEETS_FluxPercentileRatioMid35, float64
# [17] FEETS_FluxPercentileRatioMid50, float64
# [18] FEETS_FluxPercentileRatioMid65, float64
# [19] FEETS_FluxPercentileRatioMid80, float64
# [20] FEETS_Freq1_harmonics_amplitude_0, float64
# [21] FEETS_Freq1_harmonics_amplitude_1, float64
# [22] FEETS_Freq1_harmonics_amplitude_2, float64
# [23] FEETS_Freq1_harmonics_amplitude_3, float64
# [24] FEETS_Freq1_harmonics_rel_phase_0, float64
# [25] FEETS_Freq1_harmonics_rel_phase_1, float64
# [26] FEETS_Freq1_harmonics_rel_phase_2, float64
# [27] FEETS_Freq1_harmonics_rel_phase_3, float64
# [28] FEETS_Freq2_harmonics_amplitude_0, float64
# [29] FEETS_Freq2_harmonics_amplitude_1, float64
# [30] FEETS_Freq2_harmonics_amplitude_2, float64
# [31] FEETS_Freq2_harmonics_amplitude_3, float64
# [32] FEETS_Freq2_harmonics_rel_phase_0, float64
# [33] FEETS_Freq2_harmonics_rel_phase_1, float64
# [34] FEETS_Freq2_harmonics_rel_phase_2, float64
# [35] FEETS_Freq2_harmonics_rel_phase_3, float64
# [36] FEETS_Freq3_harmonics_amplitude_0, float64
# [37] FEETS_Freq3_harmonics_amplitude_1, float64
# [38] FEETS_Freq3_harmonics_amplitude_2, float64
# [39] FEETS_Freq3_harmonics_amplitude_3, float64
# [40] FEETS_Freq3_harmonics_rel_phase_0, float64
# [41] FEETS_Freq3_harmonics_rel_phase_1, float64
# [42] FEETS_Freq3_harmonics_rel_phase_2, float64
# [43] FEETS_Freq3_harmonics_rel_phase_3, float64
# [44] FEETS_Gskew, float64
# [45] FEETS_LinearTrend, float64
# [46] FEETS_MaxSlope, float64
# [47] FEETS_Mean, float64
# [48] FEETS_Meanvariance, float64
# [49] FEETS_MedianAbsDev, float64
# [50] FEETS_MedianBRP, float64
# [51] FEETS_PairSlopeTrend, float64
# [52] FEETS_PercentAmplitude, float64
# [53] FEETS_PercentDifferenceFluxPercentile, float64
# [54] FEETS_PeriodLS, float64
# [55] FEETS_Period_fit, float64
# [56] FEETS_Psi_CS, float64
# [57] FEETS_Psi_eta, float64
# [58] FEETS_Q31, float64
# [59] FEETS_Rcs, float64
# [60] FEETS_Skew, float64
# [61] FEETS_SlottedA_length, float64
# [62] FEETS_SmallKurtosis, float64
# [63] FEETS_Std, float64
# [64] FEETS_StetsonK, float64
# [65] FEETS_StetsonK_AC, float64
# [66] FEETS_StructureFunction_index_21, float64
# [67] FEETS_StructureFunction_index_31, float64
# [68] FEETS_StructureFunction_index_32, float64

# %%
APO_ZTF_Photometery = pd.read_csv('MergedAPOGEEZTF_Data.csv')
display(all_features)
# Out:
#                      oid filtercode         source_id_01     apogee_id_01  \
# 0     2M00000317+5821383         zg   422737314373993984  806104300021105
# 1     2M00000546+6152107         zg   429530195985183744  806108200000898
# 2     2M00000549+1524008         zg  2772085696588395776  499115200000339
# 3     2M00000549+1524008         zr  2772085696588395776  499115200000339
# 4     2M00000549+1524008         zi  2772085696588395776  499115200000339
# ...                  ...        ...                  ...              ...
# 2100  2M00264472+5754521         zr   421924706561379712  773115100018757
# 2101  2M00264513+5621329         zg   421724281904012928  773111100010058
# 2102  2M00264513+5621329         zr   421724281904012928  773111100010058
# 2103  2M00264514+7525370         zg   539553106195073920  854107300001200
# 2104  2M00264514+7525370         zr   539553106195073920  854107300001200
#
#       FEETS_ra  FEETS_dec  FEETS_Amplitude  FEETS_AndersonDarling  \
# 0     0.013233  58.360631         0.092366               1.000000
# 1     0.022897  61.869629         0.077303               1.000000
# 2     0.022915  15.399985         0.042002               1.000000
# 3     0.022915  15.399985         0.045834               1.000000
# 4     0.022915  15.399985         0.040320               1.000000
# ...        ...        ...              ...                    ...
# 2100  6.686432  57.914492         0.042459               1.000000
# 2101  6.688154  56.359128         0.112163               0.996984
# 2102  6.688154  56.359128         0.115139               1.000000
# 2103  6.688064  75.427032         0.069418               1.000000
# 2104  6.688064  75.427032         0.034038               1.000000
#
#       FEETS_Autocor_length  FEETS_Beyond1Std  ...  FEETS_Rcs  FEETS_Skew  \
# 0                      1.0          0.173189  ...   0.209585   -1.953084
# 1                      1.0          0.156791  ...   0.167867    2.323520
# 2                      1.0          0.065646  ...   0.063496   -9.220631
# 3                      1.0          0.054963  ...   0.047779   -2.468877
# 4                      1.0          0.099010  ...   0.086717    5.366229
# ...                    ...               ...  ...        ...         ...
# 2100                   1.0          0.017921  ...   0.055373   21.377780
# 2101                   3.0          0.290875  ...   0.125134   -0.369533
# 2102                   5.0          0.268496  ...   0.186696   -0.246111
# 2103                   1.0          0.197309  ...   0.145798    1.717456
# 2104                   1.0          0.086134  ...   0.074515    1.683393
#
#       FEETS_SlottedA_length  FEETS_SmallKurtosis  FEETS_Std  FEETS_StetsonK  \
# 0                       1.0            42.886313   0.058062        0.633054
# 1                       1.0            27.294514   0.045306        0.640288
# 2                       1.0           143.120317   0.038214        0.429507
# 3                       1.0           146.464150   0.043700        0.416801
# 4                       1.0            54.507330   0.028932        0.492611
# ...                     ...                  ...        ...             ...
# 2100                    1.0           543.947119   0.079398        0.249590
# 2101                    7.0             4.459043   0.061704        0.780748
# 2102                   13.0             1.838520   0.057020        0.759456
# 2103                    2.0            17.459482   0.038561        0.671115
# 2104                    1.0            25.909725   0.025389        0.543084
#
#       FEETS_StetsonK_AC  FEETS_StructureFunction_index_21  \
# 0              0.475413                          2.080292
# 1              0.593543                          1.421371
# 2              0.459191                          3.122827
# 3              0.383977                          2.474708
# 4              0.489438                          1.942954
# ...                 ...                               ...
# 2100           0.318702                          2.261789
# 2101           0.839196                          1.769848
# 2102           0.823022                          2.078621
# 2103           0.613072                          1.255667
# 2104           0.535157                          1.971852
#
#       FEETS_StructureFunction_index_31  FEETS_StructureFunction_index_32
# 0                             3.250333                          1.595917
# 1                             1.507039                          1.400216
# 2                             5.998420                          2.028486
# 3                             4.165865                          1.700804
# 4                             3.153580                          2.124146
# ...                                ...                               ...
# 2100                          3.881672                          1.869999
# 2101                          2.462687                          1.459912
# 2102                          3.203380                          1.553684
# 2103                          0.952338                          1.182023
# 2104                          3.003503                          1.846058
#
# [2105 rows x 69 columns]

# %%
# Plot for combined_light_curves
plt.figure(figsize=(10, 6))
plt.scatter(APO_ZTF_Photometery['ZTF_ra'], APO_ZTF_Photometery['ZTF_dec'], s = 1, alpha=0.5, label='Combi"ned Light Curves')
plt.title('RA vs DEC - Combined Light Curves')
plt.xlabel('Right Ascension')
plt.ylabel('Declination')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /astro/users/ifc2002/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Plot for all_features
plt.figure(figsize=(10, 6))
plt.scatter(all_features['FEETS_ra'], all_features['FEETS_dec'], color='red',s =1, alpha=0.5, label='All Features')
plt.title('RA vs DEC - All Features')
plt.xlabel('Right Ascension')
plt.ylabel('Declination')
plt.legend()
plt.grid(True)
plt.show()

# %%
display(all_features['apogee_id_01'],all_features['oid'])
display(APO_ZTF_Photometery['apogee_id_01'],APO_ZTF_Photometery['oid'] )
# Out:
# 0       806104300021105
# 1       806108200000898
# 2       499115200000339
# 3       499115200000339
# 4       499115200000339
#              ...
# 2100    773115100018757
# 2101    773111100010058
# 2102    773111100010058
# 2103    854107300001200
# 2104    854107300001200
# Name: apogee_id_01, Length: 2105, dtype: int64
# 0       2M00000317+5821383
# 1       2M00000546+6152107
# 2       2M00000549+1524008
# 3       2M00000549+1524008
# 4       2M00000549+1524008
#                ...
# 2100    2M00264472+5754521
# 2101    2M00264513+5621329
# 2102    2M00264513+5621329
# 2103    2M00264514+7525370
# 2104    2M00264514+7525370
# Name: oid, Length: 2105, dtype: object
# 0         2M00000002+7417074
# 1         2M00000002+7417074
# 2         2M00000317+5821383
# 3         2M00000317+5821383
# 4         2M00000317+5821383
#                  ...
# 256400    2M23595606+6251121
# 256401    2M23595606+6251121
# 256402    2M23595676+7918072
# 256403    2M23595676+7918072
# 256404    2M23595676+7918072
# Name: apogee_id_01, Length: 256405, dtype: object
# 0         1880109200004512
# 1         1863112200001427
# 2          832101400026565
# 3          806104300021105
# 4          773116200002829
#                 ...
# 256400     806112300003804
# 256401     832109400032699
# 256402    1881107200006325
# 256403     854116100006510
# 256404     868113200006561
# Name: oid, Length: 256405, dtype: int64

# %%
df1 = all_features
df2 = APO_ZTF_Photometery
#this is patch for bug in stage 3 where oid and apogee id got swapped
df1 = df1.rename(columns={'apogee_id_01': 'oid','oid': 'apogee_id_01'})#bug in stage 3 has been reomved, on fuutre runs comment this out 

df2 = df2.rename(columns={'apogee_id_01': 'APOGEE_ID'})
df2 = df2.drop(columns={'oid','source_id_01'})
display(df2['APOGEE_ID'].dtype,df2['APOGEE_ID'].dtype)
display(df2.columns)
print(len(df1.columns),len(df2.columns))

# Exclude 'APOGEE_ID' from columns_to_merge as it will be explicitly included in the merge
columns_to_merge = df2.columns[df2.columns != 'APOGEE_ID']

# Merge df2 columns to df1 based on the matching condition df1['apogee_id_01'] == df2['APOGEE_ID']
MasterDF = pd.merge(df1, df2[['APOGEE_ID'] + list(columns_to_merge)], left_on='apogee_id_01', right_on='APOGEE_ID', how='left')

# Drop the redundant column 'APOGEE_ID' after merge
MasterDF.drop(columns=['APOGEE_ID'], inplace=True)
# Drop the redundant column 'APOGEE_ID' after merge
MasterDF.drop(columns=['ZTF_filtercode'], inplace=True)
display(MasterDF.head())
# Out:
# dtype('O')
# dtype('O')
# Index(['ZTF_cntr_01', 'ZTF_dist_x', 'ZTF_pang_x', 'APOGEE_ID', 'ZTF_ra_01',
#        'ZTF_dec_01', 'ZTF_ra', 'ZTF_dec', 'ZTF_field', 'ZTF_ccdid',
#        ...
#        'GAIAEDR3_PHOT_RP_MEAN_MAG', 'GAIAEDR3_R_MED_GEO', 'GAIAEDR3_R_LO_GEO',
#        'GAIAEDR3_R_HI_GEO', 'GAIAEDR3_R_MED_PHOTOGEO',
#        'GAIAEDR3_R_LO_PHOTOGEO', 'GAIAEDR3_R_HI_PHOTOGEO', 'APOGEE_FE_H',
#        'APOGEE_FE_H_ERR', 'APOGEE_FE_H_FLAG'],
#       dtype='object', length=101)
# 69 101
#          apogee_id_01 filtercode        source_id_01              oid  \
# 0  2M00000317+5821383         zg  422737314373993984  806104300021105
# 1  2M00000317+5821383         zg  422737314373993984  806104300021105
# 2  2M00000317+5821383         zg  422737314373993984  806104300021105
# 3  2M00000546+6152107         zg  429530195985183744  806108200000898
# 4  2M00000546+6152107         zg  429530195985183744  806108200000898
#
#    FEETS_ra  FEETS_dec  FEETS_Amplitude  FEETS_AndersonDarling  \
# 0  0.013233  58.360631         0.092366                    1.0
# 1  0.013233  58.360631         0.092366                    1.0
# 2  0.013233  58.360631         0.092366                    1.0
# 3  0.022897  61.869629         0.077303                    1.0
# 4  0.022897  61.869629         0.077303                    1.0
#
#    FEETS_Autocor_length  FEETS_Beyond1Std  ...  GAIAEDR3_PHOT_RP_MEAN_MAG  \
# 0                   1.0          0.173189  ...                    10.0278
# 1                   1.0          0.173189  ...                    10.0278
# 2                   1.0          0.173189  ...                    10.0278
# 3                   1.0          0.156791  ...                    10.6035
# 4                   1.0          0.156791  ...                    10.6035
#
#    GAIAEDR3_R_MED_GEO  GAIAEDR3_R_LO_GEO  GAIAEDR3_R_HI_GEO  \
# 0           2577.4783          2455.5142          2708.9587
# 1           2577.4783          2455.5142          2708.9587
# 2           2577.4783          2455.5142          2708.9587
# 3           2539.6504          2461.3600          2642.7383
# 4           2539.6504          2461.3600          2642.7383
#
#    GAIAEDR3_R_MED_PHOTOGEO  GAIAEDR3_R_LO_PHOTOGEO  GAIAEDR3_R_HI_PHOTOGEO  \
# 0                2599.1533               2482.8160               2716.9980
# 1                2599.1533               2482.8160               2716.9980
# 2                2599.1533               2482.8160               2716.9980
# 3                2590.0790               2493.9097               2710.1824
# 4                2590.0790               2493.9097               2710.1824
#
#    APOGEE_FE_H  APOGEE_FE_H_ERR  APOGEE_FE_H_FLAG
# 0     -0.28179         0.009265                 0
# 1     -0.28179         0.009265                 0
# 2     -0.28179         0.009265                 0
# 3     -0.28340         0.008882                 0
# 4     -0.28340         0.008882                 0
#
# [5 rows x 168 columns]

# %%
counter = 0
for col in MasterDF.columns:
    print(f"[{counter}] {col}")
    counter = counter + 1
# Out:
# [0] apogee_id_01
# [1] filtercode
# [2] source_id_01
# [3] oid
# [4] FEETS_ra
# [5] FEETS_dec
# [6] FEETS_Amplitude
# [7] FEETS_AndersonDarling
# [8] FEETS_Autocor_length
# [9] FEETS_Beyond1Std
# [10] FEETS_CAR_mean
# [11] FEETS_CAR_sigma
# [12] FEETS_CAR_tau
# [13] FEETS_Con
# [14] FEETS_Eta_e
# [15] FEETS_FluxPercentileRatioMid20
# [16] FEETS_FluxPercentileRatioMid35
# [17] FEETS_FluxPercentileRatioMid50
# [18] FEETS_FluxPercentileRatioMid65
# [19] FEETS_FluxPercentileRatioMid80
# [20] FEETS_Freq1_harmonics_amplitude_0
# [21] FEETS_Freq1_harmonics_amplitude_1
# [22] FEETS_Freq1_harmonics_amplitude_2
# [23] FEETS_Freq1_harmonics_amplitude_3
# [24] FEETS_Freq1_harmonics_rel_phase_0
# [25] FEETS_Freq1_harmonics_rel_phase_1
# [26] FEETS_Freq1_harmonics_rel_phase_2
# [27] FEETS_Freq1_harmonics_rel_phase_3
# [28] FEETS_Freq2_harmonics_amplitude_0
# [29] FEETS_Freq2_harmonics_amplitude_1
# [30] FEETS_Freq2_harmonics_amplitude_2
# [31] FEETS_Freq2_harmonics_amplitude_3
# [32] FEETS_Freq2_harmonics_rel_phase_0
# [33] FEETS_Freq2_harmonics_rel_phase_1
# [34] FEETS_Freq2_harmonics_rel_phase_2
# [35] FEETS_Freq2_harmonics_rel_phase_3
# [36] FEETS_Freq3_harmonics_amplitude_0
# [37] FEETS_Freq3_harmonics_amplitude_1
# [38] FEETS_Freq3_harmonics_amplitude_2
# [39] FEETS_Freq3_harmonics_amplitude_3
# [40] FEETS_Freq3_harmonics_rel_phase_0
# [41] FEETS_Freq3_harmonics_rel_phase_1
# [42] FEETS_Freq3_harmonics_rel_phase_2
# [43] FEETS_Freq3_harmonics_rel_phase_3
# [44] FEETS_Gskew
# [45] FEETS_LinearTrend
# [46] FEETS_MaxSlope
# [47] FEETS_Mean
# [48] FEETS_Meanvariance
# [49] FEETS_MedianAbsDev
# [50] FEETS_MedianBRP
# [51] FEETS_PairSlopeTrend
# [52] FEETS_PercentAmplitude
# [53] FEETS_PercentDifferenceFluxPercentile
# [54] FEETS_PeriodLS
# [55] FEETS_Period_fit
# [56] FEETS_Psi_CS
# [57] FEETS_Psi_eta
# [58] FEETS_Q31
# [59] FEETS_Rcs
# [60] FEETS_Skew
# [61] FEETS_SlottedA_length
# [62] FEETS_SmallKurtosis
# [63] FEETS_Std
# [64] FEETS_StetsonK
# [65] FEETS_StetsonK_AC
# [66] FEETS_StructureFunction_index_21
# [67] FEETS_StructureFunction_index_31
# [68] FEETS_StructureFunction_index_32
# [69] ZTF_cntr_01
# [70] ZTF_dist_x
# [71] ZTF_pang_x
# [72] ZTF_ra_01
# [73] ZTF_dec_01
# [74] ZTF_ra
# [75] ZTF_dec
# [76] ZTF_field
# [77] ZTF_ccdid
# [78] ZTF_qid
# [79] ZTF_fid
# [80] ZTF_ngoodobs
# [81] ZTF_ngoodobsrel
# [82] ZTF_nobs
# [83] ZTF_nobsrel
# [84] ZTF_refchi
# [85] ZTF_refmag
# [86] ZTF_refmagerr
# [87] ZTF_refsharp
# [88] ZTF_refsnr
# [89] ZTF_astrometricrms
# [90] ZTF_chisq
# [91] ZTF_con
# [92] ZTF_lineartrend
# [93] ZTF_magrms
# [94] ZTF_maxmag
# [95] ZTF_maxslope
# [96] ZTF_meanmag
# [97] ZTF_medianabsdev
# [98] ZTF_medianmag
# [99] ZTF_medmagerr
# [100] ZTF_minmag
# [101] ZTF_nabovemeanbystd_1
# [102] ZTF_nabovemeanbystd_3
# [103] ZTF_nabovemeanbystd_5
# [104] ZTF_nbelowmeanbystd_1
# [105] ZTF_nbelowmeanbystd_3
# [106] ZTF_nbelowmeanbystd_5
# [107] ZTF_nconsecabovemeanbystd_1
# [108] ZTF_nconsecabovemeanbystd_3
# [109] ZTF_nconsecabovemeanbystd_5
# [110] ZTF_nconsecbelowmeanbystd_1
# [111] ZTF_nconsecbelowmeanbystd_3
# [112] ZTF_nconsecbelowmeanbystd_5
# [113] ZTF_nconsecfrommeanbystd_1
# [114] ZTF_nconsecfrommeanbystd_3
# [115] ZTF_nconsecfrommeanbystd_5
# [116] ZTF_nmedianbufferrange
# [117] ZTF_npairposslope
# [118] ZTF_percentiles_05
# [119] ZTF_percentiles_10
# [120] ZTF_percentiles_175
# [121] ZTF_percentiles_25
# [122] ZTF_percentiles_325
# [123] ZTF_percentiles_40
# [124] ZTF_percentiles_60
# [125] ZTF_percentiles_675
# [126] ZTF_percentiles_75
# [127] ZTF_percentiles_825
# [128] ZTF_percentiles_90
# [129] ZTF_percentiles_95
# [130] ZTF_skewness
# [131] ZTF_smallkurtosis
# [132] ZTF_stetsonj
# [133] ZTF_stetsonk
# [134] ZTF_vonneumannratio
# [135] ZTF_weightedmagrms
# [136] ZTF_weightedmeanmag
# [137] ZTF_ROW_IDX
# [138] ZTF_ROW_NUM
# [139] APOGEE_RA
# [140] APOGEE_DEC
# [141] APOGEE_TEFF_SPEC
# [142] APOGEE_LOGG_SPEC
# [143] APOGEE_TEFF
# [144] APOGEE_TEFF_ERR
# [145] APOGEE_LOGG
# [146] APOGEE_LOGG_ERR
# [147] APOGEE_RV_TEFF
# [148] APOGEE_RV_LOGG
# [149] APOGEE_RV_FEH
# [150] GAIAEDR3_PARALLAX
# [151] GAIAEDR3_PARALLAX_ERROR
# [152] GAIAEDR3_PMRA
# [153] GAIAEDR3_PMRA_ERROR
# [154] GAIAEDR3_PMDEC
# [155] GAIAEDR3_PMDEC_ERROR
# [156] GAIAEDR3_PHOT_G_MEAN_MAG
# [157] GAIAEDR3_PHOT_BP_MEAN_MAG
# [158] GAIAEDR3_PHOT_RP_MEAN_MAG
# [159] GAIAEDR3_R_MED_GEO
# [160] GAIAEDR3_R_LO_GEO
# [161] GAIAEDR3_R_HI_GEO
# [162] GAIAEDR3_R_MED_PHOTOGEO
# [163] GAIAEDR3_R_LO_PHOTOGEO
# [164] GAIAEDR3_R_HI_PHOTOGEO
# [165] APOGEE_FE_H
# [166] APOGEE_FE_H_ERR
# [167] APOGEE_FE_H_FLAG

# %%
# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_TEFF'], MasterDF['APOGEE_TEFF_SPEC'], s = 1, alpha=0.5, label='TEFF vs TEFF_SPEC')
plt.title('TEFF vs TEFF_SPEC - APOGEE')
plt.xlabel('TEFF')
plt.ylabel('TEFF_SPEC')
plt.legend()
plt.grid(True)
plt.show()

# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_TEFF_SPEC'], MasterDF['APOGEE_RV_TEFF'],  s = 1, color='red', alpha=0.5, label='RV_TEFF vs TEFF_SPEC')
plt.title('RV_TEFF vs TEFF_SPEC- APOGEE')
plt.xlabel('TEFF_SPEC')
plt.ylabel('RV_TEFF')
plt.legend()
plt.grid(True)
plt.show()

# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_TEFF'], MasterDF['APOGEE_RV_TEFF'], s = 1,color='green', alpha=0.5, label='TEFF vs RV_TEFF')
plt.title('TEFF vs RV_TEFF - APOGEE')
plt.xlabel('TEFF')
plt.ylabel('RV_TEFF')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_LOGG'], MasterDF['APOGEE_LOGG_SPEC'], s = 1, alpha=0.5, label='LOGG vs LOGG_SPEC')
plt.title('LOGG vs LOGG_SPEC - APOGEE')
plt.xlabel('LOGG')
plt.ylabel('LOGG_SPEC')
plt.legend()
plt.grid(True)
plt.show()

# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_LOGG_SPEC'], MasterDF['APOGEE_RV_LOGG'],  s = 1, color='red', alpha=0.5, label='RV_LOGG vs LOGG_SPEC')
plt.title('RV_LOGG vs LOGG_SPEC- APOGEE')
plt.xlabel('LOGG_SPEC')
plt.ylabel('RV_LOGG')
plt.legend()
plt.grid(True)
plt.show()

# Plot for combined_light_curves
plt.figure(figsize=(8, 8))
plt.scatter(MasterDF['APOGEE_LOGG'], MasterDF['APOGEE_RV_LOGG'], s = 1,color='green', alpha=0.5, label='LOGG vs RV_LOGG')
plt.title('LOGG vs RV_LOGG - APOGEE')
plt.xlabel('LOGG')
plt.ylabel('RV_LOGG')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Just save it as a CSV

# %%
MasterDF.to_csv('feetsZTFandAPOGEE_zgi.csv', index = False)
