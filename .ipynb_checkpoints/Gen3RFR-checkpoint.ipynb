# %%
import joblib
import pandas as pd
import numpy as np
import random
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, max_error, explained_variance_score

# %%
# Load the Random Forest model from the joblib file
#model_path = 'RFRexp5-3-Monster/RUN7/random_forest_regressor.joblib'
model_path = 'RFRGen3/random_forest_regressor.joblib'
rfr = joblib.load(model_path)
df = pd.DataFrame(columns=['n', 'n_estimators', 'rand', 'mse', 'r_squared'])
# Load your dataset (replace 'path_to_your_data.csv' with your actual dataset path)
data_path = 'TrainingSetundLOGG.csv'
data = pd.read_csv(data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Load the Random Forest model from the joblib file
#       2 #model_path = 'RFRexp5-3-Monster/RUN7/random_forest_regressor.joblib'
#       3 model_path = 'RFRGen3/random_forest_regressor.joblib'
# ----> 4 rfr = joblib.load(model_path)
#       5 df = pd.DataFrame(columns=['n', 'n_estimators', 'rand', 'mse', 'r_squared'])
#       6 # Load your dataset (replace 'path_to_your_data.csv' with your actual dataset path)
#
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'RFRGen3/random_forest_regressor.joblib'

# %%
# Dataset has a target column 'APOGEE_LOGG' and features in the remaining columns
features = data.drop(columns=['APOGEE_LOGG'])
target = data['APOGEE_LOGG']

# The preprocessing pipeline
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Step 1: Impute missing values with mean
    ('scaling', StandardScaler()),  # Step 2: Standardize the features
    ('feature_selection', SelectKBest(score_func=f_regression, k=11)),  # Step 3: Select top 65 features
])

# Fit and transform the data using the pipeline
X_preprocessed = pipeline.fit_transform(features, target)

# Split data into training and test sets
randTrain = 8248 #random.randint(0, 10000)
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, target, test_size=0.12, random_state=randTrain)

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [8,16, 32, 64, 128, 512,1024],      # Number of trees in the forest
    'max_features': ['auto', 'sqrt'],    # Number of features to consider at every split
    'max_depth': [10, 20, None],         # Maximum number of levels in tree
    'min_samples_split': [2, 5, 10],     # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4],       # Minimum number of samples required at each leaf node
    'bootstrap': [True, False]           # Method of selecting samples for training each tree
}

# Initialize a new RandomForestRegressor model
new_rfr = RandomForestRegressor(random_state=randTrain)

# Create a pipeline that includes the preprocessing steps and the new RandomForestRegressor
full_pipeline = Pipeline([
    ('preprocessing', pipeline),
    ('regressor', new_rfr)
])

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=new_rfr, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters and the best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f'Best hyperparameters: {best_params}')

# Make predictions using the best model
best_predictions = best_model.predict(X_test)

# Evaluate the best model
mse = mean_squared_error(y_test, best_predictions)
r_squared = r2_score(y_test, best_predictions)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r_squared}')

# Save the best model
best_model_path = 'path_to_save_best_model.joblib'
joblib.dump(best_model, best_model_path)
print(f'Best model saved to {best_model_path}')
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time= 5.0min
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time= 2.3min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.5min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time= 3.1min
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time= 9.8min
# /astro/users/ifc2002/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time= 4.8min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time= 3.3min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.7min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time= 4.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time= 3.7min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time= 9.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time= 3.5min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time= 9.4min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 3.4min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time= 2.5min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time= 3.1min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time= 5.5min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time= 9.8min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 5.0min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 3.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time= 5.0min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 3.4min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time= 2.3min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time= 8.1min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time= 3.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time= 9.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time= 3.6min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time= 9.6min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time= 9.4min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time= 7.7min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time= 9.5min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time= 8.1min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time= 3.2min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time= 3.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time= 7.4min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.6min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time= 2.3min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time= 3.1min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 2.4min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time= 7.7min
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.9min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 5.0min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time= 4.9min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time= 4.7min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time= 2.3min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.7min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 2.5min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time= 7.7min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time= 2.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=3000; total time= 9.8min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time= 8.0min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time= 3.7min
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=3000; total time=   0.0s
# ...
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 4.2min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time= 5.5min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time= 8.1min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 3.8min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=22.5min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=18.8min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 4.5min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time= 8.8min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=18.8min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=700; total time= 6.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time= 6.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 4.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=18.6min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=17.1min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=3000; total time=14.7min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=24.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 4.4min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time= 6.0min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 4.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=18.6min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 3.0min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 5.2min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time= 7.4min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1500; total time= 9.8min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=15.7min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time= 4.9min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time= 3.5min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time= 5.6min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=11.7min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time= 5.2min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=39.4min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=3000; total time=15.1min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=14.9min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=700; total time= 5.7min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 3.9min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=700; total time= 5.6min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 4.7min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=13.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 4.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=17.7min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time= 5.1min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=21.4min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time= 5.2min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=16.9min
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1500; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 3.2min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time= 4.9min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=16.2min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time= 5.7min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time= 5.5min
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time= 5.0min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=3000; total time=14.4min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 8.3min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 4.0min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=3000; total time=22.1min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time= 8.3min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=700; total time= 5.2min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=16.9min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 9.9min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time= 8.6min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time= 7.7min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=17.0min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time= 6.4min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time= 8.7min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time= 7.6min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=3000; total time=17.1min
# Best hyperparameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 3000}
# Mean Squared Error: 0.17483156772862088
# R^2 Score: 0.9070879411383459
# Best model saved to path_to_save_best_model.joblib

# %%
# Initialize the DataFrame to collect results
results_df = pd.DataFrame(columns=[
    'Run', 'N_Estimators', 'Random Training State', 'Random RFR State', 'MSE', 'R^2', 'Adjusted R^2', 'MAE', 
    'MedAE', 'Maximum Error', 'Explained Variance', 'Mean Residual Difference', 'Sigma (Std of Residuals)', 
    'Residual Sum of Squares', 'Total Sum of Squares', 'Mean Squared Log Error', 'Mean Bias Deviation', 
    'Max Depth', 'Min Samples Split', 'Min Samples Leaf'
])

# Load the Random Forest model from the joblib file
model_path = 'BestModelGen3.joblib'
rfr = joblib.load(model_path)

# Load your dataset (replace 'path_to_your_data.csv' with your actual dataset path)
data_path = 'TrainingSetundLOGG.csv'
data = pd.read_csv(data_path)

# Assume your dataset has a target column 'APOGEE_LOGG' and features in the remaining columns
features = data.drop(columns=['APOGEE_LOGG'])
target = data['APOGEE_LOGG']

# Create the preprocessing pipeline
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Step 1: Impute missing values with mean
    ('scaling', StandardScaler()),  # Step 2: Standardize the features
    ('feature_selection', SelectKBest(score_func=f_regression, k=11)),  # Step 3: Select top 65 features
])

# Fit and transform the data using the pipeline
X_preprocessed = pipeline.fit_transform(features, target)

# Split data into training and test sets
randTrain = 4180  # Fixed random state 
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, target, test_size=0.12, random_state=randTrain)

# Make predictions using the loaded model
y_pred = rfr.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)
max_err = max_error(y_test, y_pred)
explained_var = explained_variance_score(y_test, y_pred)

# Calculate residuals
residuals = y_test - y_pred

# Calculate mean residual difference and sigma (standard deviation of residuals)
mean_residual = np.mean(residuals)
sigma = np.std(residuals)

# Calculate additional statistics
residual_sum_of_squares = np.sum(residuals ** 2)
total_sum_of_squares = np.sum((y_test - np.mean(y_test)) ** 2)
adjusted_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)
mean_squared_log_error = np.mean((np.log1p(y_pred) - np.log1p(y_test)) ** 2)
mean_bias_deviation = np.mean(np.abs(residuals - mean_residual))

# Extract hyperparameters
n_estimators = rfr.get_params()['n_estimators']
max_depth = rfr.get_params()['max_depth']
min_samples_split = rfr.get_params()['min_samples_split']
min_samples_leaf = rfr.get_params()['min_samples_leaf']

# Append a new row to the DataFrame
n = 1  # Example run number, adjust as necessary
new_row = pd.DataFrame({
    'Run': [n],
    'N_Estimators': [n_estimators],
    'Random Training State': [randTrain],
    'Random RFR State': [3012],  # Adjust as necessary
    'MSE': [mse],
    'R^2': [r2],
    'Adjusted R^2': [adjusted_r2],
    'MAE': [mae],
    'MedAE': [medae],
    'Maximum Error': [max_err],
    'Explained Variance': [explained_var],
    'Mean Residual Difference': [mean_residual],
    'Sigma (Std of Residuals)': [sigma],
    'Residual Sum of Squares': [residual_sum_of_squares],
    'Total Sum of Squares': [total_sum_of_squares],
    'Mean Squared Log Error': [mean_squared_log_error],
    'Mean Bias Deviation': [mean_bias_deviation],
    'Max Depth': [max_depth],
    'Min Samples Split': [min_samples_split],
    'Min Samples Leaf': [min_samples_leaf]
})

# Append the new row to the main DataFrame
results_df = results_df.append(new_row, ignore_index=True)

# Display the updated DataFrame
display(results_df)

# Save the results DataFrame to a CSV file
results_df_path = 'predictions_vs_actualGen3-1.csv'
results_df.to_csv(results_df_path, index=False)

print(f'Results saved to {results_df_path}')
# Out:
# /tmp/ipykernel_90562/456314976.py:92: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append(new_row, ignore_index=True)
#   Run N_Estimators Random Training State Random RFR State      MSE       R^2  \
# 0   1         3000                  4180             3012  0.01787  0.990587
#
#   Adjusted R^2      MAE MedAE Maximum Error Explained Variance  \
# 0     0.990572  0.02442   0.0      2.583343           0.990587
#
#   Mean Residual Difference Sigma (Std of Residuals) Residual Sum of Squares  \
# 0                 0.000461                 0.133679               126.91401
#
#   Total Sum of Squares Mean Squared Log Error Mean Bias Deviation Max Depth  \
# 0         13482.772453               0.001482            0.024831      None
#
#   Min Samples Split Min Samples Leaf
# 0                 2                1
# Results saved to predictions_vs_actualGen3-1.csv

# %%
# Print the predictions vs actual values
predictions = rfr.predict(X_test)

# Print the predictions vs actual values
predictions_df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
predictions_df = predictions_df.sort_values(by=['Actual'])
predictions_df['Difference'] = predictions_df['Actual'] - predictions_df['Predicted']
predictions_df['Absolute Error'] = np.abs(predictions_df['Difference'])
predictions_df['Percentage Error'] = (predictions_df['Absolute Error'] / predictions_df['Actual']) * 100

display(predictions_df)
# Out:
#          Actual  Predicted    Difference  Absolute Error  Percentage Error
# 33752 -0.369348  -0.369348  1.415534e-14    1.415534e-14     -3.832518e-12
# 29232 -0.257658  -0.257658  9.270362e-15    9.270362e-15     -3.597932e-12
# 48109 -0.239356  -0.239356 -1.054712e-14    1.054712e-14     -4.406462e-12
# 21770 -0.235335  -0.235335  6.800116e-15    6.800116e-15     -2.889548e-12
# 41835 -0.229204   0.690741 -9.199453e-01    9.199453e-01     -4.013656e+02
# ...         ...        ...           ...             ...               ...
# 17539  4.747313   4.747313  1.243450e-13    1.243450e-13      2.619271e-12
# 58383  4.764966   4.764967 -2.966516e-13    2.966516e-13      6.225681e-12
# 18990  4.793125   4.793125 -1.199041e-13    1.199041e-13      2.501585e-12
# 39376  5.125745   5.125745  2.389200e-13    2.389200e-13      4.661176e-12
# 12870  5.186769   5.186770 -7.638334e-14    7.638334e-14      1.472657e-12
#
# [7102 rows x 5 columns]

# %%
plt.ylim
# Out:
# <function matplotlib.pyplot.ylim(*args, **kwargs) -> 'tuple[float, float]'>

# %%
# Plot predicted vs actual with a line of slope 1
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Predicted'], color='blue', alpha=0.1)
plt.plot([predictions_df['Actual'].min(), predictions_df['Actual'].max()],
         [predictions_df['Actual'].min(), predictions_df['Actual'].max()],
         color='red', linestyle='--', linewidth=2)  # Line with slope of 1
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Predicted Values', fontsize=14)
plt.title('Scatter plot of Predicted vs. Actual Values', fontsize=18)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot actual vs. actual - predicted
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Difference'], color='blue', alpha=0.1)
plt.axhline(0, color='red', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('A-P', fontsize=14)
plt.title('Scatter plot of Difference vs. Actual Values', fontsize=18)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot actual vs. actual - predicted
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Predicted'], predictions_df['Difference'], color='blue', alpha=0.05)
plt.axhline(0, color='red', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.xlabel('Predicted Values', fontsize=14)
plt.ylabel('A-P', fontsize=14)
plt.title('Scatter plot of Difference vs. Predicted Values', fontsize=18)
plt.grid(True)
plt.show()

# %%
# Plot 1: Residual plot
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Difference'], color='blue', alpha=0.1)
plt.axhline(0, color='red', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Actual - Predicted', fontsize=14)
plt.title('Residual Plot (Actual - Predicted vs. Actual)', fontsize=18)
plt.grid(True)
plt.show()

# %%
# Plot 2: Absolute Error plot
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Absolute Error'], color='blue', alpha=0.1)
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Absolute Error', fontsize=14)
plt.title('Absolute Error vs. Actual Values', fontsize=18)
plt.grid(True)
plt.show()

# %%
# Plot: Percentage Error plot on a log10 scale
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], np.abs(predictions_df['Percentage Error']), color='blue', alpha=0.1)
plt.yscale('log')
plt.axhline(1, color='red', linestyle='--')  # Add a horizontal line at y=1 for reference
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Percentage Error (log scale)', fontsize=14)
plt.title('Percentage Error vs. Actual Values (log scale)', fontsize=18)
plt.grid(True, which="both", ls="--")
plt.show()

# %%
# Plot 4: Histogram of Errors
plt.figure(figsize=(14, 10))
plt.hist(predictions_df['Absolute Error'], bins=10, color='blue', alpha=0.6)
plt.xlabel('Error (Actual - Predicted)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.yscale('log')
plt.title('Histogram of Errors', fontsize=18)
plt.grid(True)
plt.show()

# %%
import scipy.stats as stats
plt.figure(figsize=(14, 10))
stats.probplot(predictions_df['Difference'], dist="norm", plot=plt)
plt.title('QQ Plot of Errors', fontsize=18)
plt.grid(True)
plt.show()

# %%
# Calculate the standard deviation of the residuals
std_dev = np.std(predictions_df['Difference'])

# Plot residuals with standard deviation lines
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Difference'], color='blue', alpha=0.1, label='Residuals')
plt.axhline(0, color='red', linestyle='--', linewidth=1, label='Mean Error (0)')
plt.axhline(std_dev, color='green', linestyle='--', linewidth=1, label=f'+1 Std Dev ({std_dev:.2f})')
plt.axhline(-std_dev, color='green', linestyle='--', linewidth=1, label=f'-1 Std Dev ({std_dev:.2f})')
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Actual - Predicted', fontsize=14)
plt.title('Residual Plot with Standard Deviation Lines', fontsize=18)
plt.legend()
plt.grid(True)
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors

# Define the updated list of colors in RGB format
colors = [
    (180, 130, 207),
    (141, 70, 185),
    (122, 35, 171), #2
    (90, 22, 150), #2
    (70, 15, 135), 
    (0, 0, 100), #6 - 100

    (75, 120, 235),
    (71, 114, 232),#11
    (63, 94, 230), #10
    (55, 74, 228), #9
    (46, 63, 226), #8
    (10, 56, 223), #12 - 200
    


#     (120, 197, 238),
#     (112, 188, 241),
#     (105, 175, 241),
#     (100, 169, 239), 
#     (97, 160, 239),    
#     (88, 150, 237), 


 # 300 
    
    (126, 255, 40),    
    (20, 240, 30), 
    (30, 231, 67),  
    (42, 222, 82), 
    (64, 202, 94), 
    (57, 168, 87), # 400
    

    



    #(182, 255, 0), 
    #(219, 255, 0), 
    (245, 252, 0), 
    (240, 230, 2),
    (240, 222, 10), 
    (235, 200, 15),  
    (225, 188, 0),
    (205, 161, 0), #500
    
  
    (255, 176, 0), 
    (255, 165, 0),
    (255,130,0),
    (255, 100, 100), 
    (255, 50, 50), 
    (255, 0, 0) # 600
]
print(len(colors))
# Normalize the RGB values to [0, 1] range
colors = [(r / 255, g / 255, b / 255) for r, g, b in colors]

# Create a colormap object with the updated colors list
cmap = LinearSegmentedColormap.from_list("custom_gradient_with_brightened_color", colors, N=len(colors))
# Out:
# 30

# %%
# Create a ListedColormap object
cmap = mcolors.ListedColormap(colors, name='my_rainbow')

cmap.set_under('white', alpha=0)  # Make values of zero transparent
cmap_args = dict(cmap=cmap, vmin=1,vmax=500)
plt.figure(figsize=(14, 10))
#plt.scatter(results_df['Actual'], results_df['Predicted'], color='blue', alpha=0.6)
plt.hexbin(predictions_df['Actual'], predictions_df['Difference'], gridsize=50, **cmap_args)  # Using cmap_args for colormap setup
plt.axhline(0, color='red', linestyle='--', linewidth=1, label='Mean Error (0)')
plt.axhline(std_dev, color='green', linestyle='--', linewidth=1, label=f'+1 Std Dev ({std_dev:.2f})')
plt.axhline(-std_dev, color='green', linestyle='--', linewidth=1, label=f'-1 Std Dev ({std_dev:.2f})')
# plt.plot([results_df['Actual'].min(), results_df['Actual'].max()],
#        [results_df['Actual'].min(), results_df['Actual'].max()],
#         color='red', linestyle='--', linewidth=0.5)  # Line with slope of 1
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Predicted Values', fontsize=14)
plt.title('Heatmap of Predicted vs. Actual Values', fontsize=18)
plt.colorbar(label='Count')
plt.grid(True)
plt.show()

# %%
# Define the range of actual values for which you want to calculate sigma significance
min_actual_value = 4  # Replace with your minimum actual value
max_actual_value = predictions_df['Actual'].max()  # Replace with your maximum actual value

# Filter the results to include only the desired range of actual values
filteredResultsDF = predictions_df[(predictions_df['Actual'] >= min_actual_value) & (predictions_df['Actual'] <= max_actual_value)]

# Calculate the mean and standard deviation of the differences (residuals)
mean_difference = filteredResultsDF['Difference'].mean()
std_difference = filteredResultsDF['Difference'].std()

# Calculate sigma significance
sigma_significance = mean_difference / std_difference

print(f'Mean Difference: {mean_difference}')
print(f'Standard Deviation of Difference: {std_difference}')
print(f'Sigma Significance: {sigma_significance}')

mse = mean_squared_error(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])
r_squared = r2_score(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r_squared}')

plt.figure(figsize=(14, 10))
plt.hist(filteredResultsDF['Absolute Error'], bins=10, color='blue', alpha=0.6)
plt.xlabel('Error (Actual - Predicted)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.yscale('log')
plt.title('Histogram of Errors', fontsize=18)
plt.grid(True)
plt.show()
# Out:
# Mean Difference: 0.04407073199320198
# Standard Deviation of Difference: 0.21751522093862752
# Sigma Significance: 0.20260987623315177
# Mean Squared Error: 0.04922534423554124
# R^2 Score: -19.07139154401955

# %%
filteredResultsDF = predictions_df

# Calculate the mean and standard deviation of the differences (residuals)
mean_difference = filteredResultsDF['Difference'].mean()
std_difference = filteredResultsDF['Difference'].std()

# Calculate sigma significance
sigma_significance = mean_difference / std_difference

print(f'Mean Difference: {mean_difference}')
print(f'Standard Deviation of Difference: {std_difference}')
print(f'Sigma Significance: {sigma_significance}')

mse = mean_squared_error(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])
r_squared = r2_score(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r_squared}')
plt.figure(figsize=(14, 10))
plt.hist(filteredResultsDF['Difference'], bins=50, color='blue', alpha=0.6)
plt.xlabel('Error (Actual - Predicted)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.yscale('log')
plt.title('Histogram of Errors', fontsize=18)
plt.grid(True)
plt.show()
# Out:
# Mean Difference: 0.0004613907837105073
# Standard Deviation of Difference: 0.1336880045015694
# Sigma Significance: 0.003451250435150978
# Mean Squared Error: 0.01787017888688901
# R^2 Score: 0.9905869500581728

# %%
# Define the range of actual values for which you want to calculate sigma significance
min_actual_value =predictions_df['Actual'].min() # Replace with your minimum actual value
max_actual_value = results_df['Actual'].max() # Replace with your maximum actual value

# Filter the results to include only the desired range of actual values
filteredResultsDF = predictions_df[(predictions_df['Actual'] >= min_actual_value) & (predictions_df['Actual'] <= max_actual_value)]

# Calculate the mean and standard deviation of the differences (residuals)
mean_difference = filteredResultsDF['Difference'].mean()
std_difference = filteredResultsDF['Difference'].std()

# Calculate sigma significance
sigma_significance = mean_difference / std_difference

print(f'Mean Difference: {mean_difference}')
print(f'Standard Deviation of Difference: {std_difference}')
print(f'Sigma Significance: {sigma_significance}')

mse = mean_squared_error(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])
r_squared = r2_score(filteredResultsDF['Actual'], filteredResultsDF['Predicted'])

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r_squared}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Actual'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 3
#       1 # Define the range of actual values for which you want to calculate sigma significance
#       2 min_actual_value =predictions_df['Actual'].min() # Replace with your minimum actual value
# ----> 3 max_actual_value = results_df['Actual'].max() # Replace with your maximum actual value
#       5 # Filter the results to include only the desired range of actual values
#       6 filteredResultsDF = predictions_df[(predictions_df['Actual'] >= min_actual_value) & (predictions_df['Actual'] <= max_actual_value)]
#
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.conda/envs/project_meltheat_v2/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Actual'

# %%
# Calculate the standard deviation of the residuals
std_dev = np.std(predictions_df['Difference'])

# Plot residuals with standard deviation lines
plt.figure(figsize=(14, 10))
plt.scatter(filteredResultsDF['Actual'], filteredResultsDF['Difference'], color='blue', alpha=0.1, label='Residuals')
plt.axhline(0, color='red', linestyle='--', linewidth=1, label='Mean Error (0)')
plt.axhline(std_dev, color='green', linestyle='--', linewidth=1, label=f'+1 Std Dev ({std_dev:.2f})')
plt.axhline(-std_dev, color='green', linestyle='--', linewidth=1, label=f'-1 Std Dev ({std_dev:.2f})')
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Actual - Predicted', fontsize=14)
plt.title('Residual Plot with Standard Deviation Lines', fontsize=18)
plt.legend()
plt.grid(True)
plt.show()

# %%
std_dev = np.std(predictions_df['Difference'])

# Plot residuals with standard deviation lines
plt.figure(figsize=(14, 10))
plt.scatter(predictions_df['Actual'], predictions_df['Difference'], color='blue', alpha=0.6, label='Residuals')
plt.axhline(0, color='red', linestyle='--', linewidth=1, label='Mean Error (0)')
plt.axhline(std_dev, color='green', linestyle='--', linewidth=1, label=f'+1 Std Dev ({std_dev:.2f})')
plt.axhline(-std_dev, color='green', linestyle='--', linewidth=1, label=f'-1 Std Dev ({std_dev:.2f})')
plt.xlabel('Actual Values', fontsize=14)
plt.ylabel('Actual - Predicted', fontsize=14)
plt.title('Residual Plot with Standard Deviation Lines', fontsize=18)
plt.legend()
plt.grid(True)
plt.show()
