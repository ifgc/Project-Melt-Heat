# %%
import pandas as pd

# %%
# import os
from IPython.display import clear_output
import time

def print_last_lines(file_path, num_lines=100):
    clear_output(wait=True)
    with open(file_path, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        # Print the last num_lines lines
        for line in lines[-num_lines:]:
            print(line, end='')
    # Wait for 5 seconds after printing
    time.sleep(1)


while 2 > 1:
    print_last_lines('LogFor_griRun/processing.log', 5)
# Out:
# 2024-07-29 23:50:20,110 - WARNING - Filter Data Empty for 2M00045718+6854259 Source:529141899311585152 ZTF:833108100001922 and filter zi: Insufficient data points: 0
# 2024-07-29 23:50:20,111 - INFO - Processing Gaia DR3 - 529141899311585152 170/60786 APOGEE_IDs (0.28%) with batch size 5
# 2024-07-29 23:50:22,928 - INFO - Filter Data empty for zi
# 2024-07-29 23:50:22,930 - WARNING - Filter Data Empty for 2M00045724+6914335 Source:530654380634584960 ZTF:853109400010171 and filter zi: Insufficient data points: 0
# 2024-07-29 23:50:22,931 - INFO - Processing Gaia DR3 - 530654380634584960 171/60786 APOGEE_IDs (0.28%) with batch size 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      14     time.sleep(1)
#      17 while 2 > 1:
# ---> 18     print_last_lines('LogFor_griRun/processing.log', 5)
#
# Cell In[3], line 14, in print_last_lines(file_path, num_lines)
#      12         print(line, end='')
#      13 # Wait for 5 seconds after printing
# ---> 14 time.sleep(1)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('LogFor_griRun/extracted_features.csv')
display(df)
# Out:
#         Amplitude  AndersonDarling  Autocor_length  Beyond1Std   CAR_mean  \
# 0        0.092366              1.0             1.0    0.173189  26.362991
# 1        0.077303              1.0             1.0    0.156791  26.983311
# 2        0.042002              1.0             1.0    0.065646  25.642605
# 3        0.045834              1.0             1.0    0.054963  28.662140
# 4        0.040320              1.0             1.0    0.099010  26.540319
# ...           ...              ...             ...         ...        ...
# 110777   0.034481              1.0             1.0    0.035510  28.250559
# 110778   0.500515              1.0             1.0    0.310992  42.061604
# 110779   0.075620              1.0             1.0    0.234953  35.413574
# 110780   0.061153              1.0             1.0    0.084731  29.091696
# 110781   0.036490              1.0             1.0    0.033162  26.511858
#
#         CAR_sigma   CAR_tau       Con         Eta_e  FluxPercentileRatioMid20  \
# 0            10.0  0.500000  0.000000  2.969559e+03                  0.163161
# 1            10.0  0.500000  0.000000  2.263402e+03                  0.145173
# 2             0.0  0.612842  0.000000  4.412409e+05                  0.117636
# 3            10.0  0.500000  0.000822  7.590719e+05                  0.122697
# 4            10.0  0.500000  0.000000  8.390386e+03                  0.123834
# ...           ...       ...       ...           ...                       ...
# 110777       10.0  0.500000  0.000000  2.910786e+05                  0.130814
# 110778       10.0  0.500000  0.002695  8.014631e+03                  0.135243
# 110779       10.0  0.500000  0.000000  1.001963e+06                  0.150822
# 110780       10.0  0.500000  0.000000  9.087202e+03                  0.173439
# 110781       10.0  0.500000  0.002290  3.840065e+05                  0.120745
#
#         ...  StetsonK_AC  StructureFunction_index_21  \
# 0       ...     0.475413                    2.080292
# 1       ...     0.593543                    1.421371
# 2       ...     0.459191                    3.122827
# 3       ...     0.383977                    2.474708
# 4       ...     0.489438                    1.942954
# ...     ...          ...                         ...
# 110777  ...     0.695471                    3.728861
# 110778  ...     0.724257                    1.598594
# 110779  ...     0.705262                    2.018006
# 110780  ...     0.388509                    2.085577
# 110781  ...     0.542772                    3.740341
#
#         StructureFunction_index_31  StructureFunction_index_32  \
# 0                         3.250333                    1.595917
# 1                         1.507039                    1.400216
# 2                         5.998420                    2.028486
# 3                         4.165865                    1.700804
# 4                         3.153580                    2.124146
# ...                            ...                         ...
# 110777                    6.681452                    1.802718
# 110778                    1.963025                    1.295962
# 110779                    3.054998                    1.550758
# 110780                    2.824454                    1.678650
# 110781                    6.703795                    1.805011
#
#               apogee_id_01  filtercode         source_id_01              oid  \
# 0       2M00000317+5821383          zg   422737314373993984  806104300021105
# 1       2M00000546+6152107          zg   429530195985183744  806108200000898
# 2       2M00000549+1524008          zg  2772085696588395776  499115200000339
# 3       2M00000549+1524008          zr  2772085696588395776  499115200000339
# 4       2M00000549+1524008          zi  2772085696588395776  499115200000339
# ...                    ...         ...                  ...              ...
# 110777  2M00044965+5616014          zr   420970021229284480  773112200010392
# 110778  2M00045087+6838020          zg   529113342070253312  833108100004297
# 110779  2M00045087+6838020          zr   529113342070253312  833108100004297
# 110780  2M00045181+5517074          zg   420446615036203136  773112300026969
# 110781  2M00045181+5517074          zr   420446615036203136  773112300026969
#
#               ra        dec
# 0       0.013233  58.360631
# 1       0.022897  61.869629
# 2       0.022915  15.399985
# 3       0.022915  15.399985
# 4       0.022915  15.399985
# ...          ...        ...
# 110777  1.206945  56.267097
# 110778  1.212071  68.633956
# 110779  1.212071  68.633956
# 110780  1.215930  55.285476
# 110781  1.215930  55.285476
#
# [110782 rows x 69 columns]
